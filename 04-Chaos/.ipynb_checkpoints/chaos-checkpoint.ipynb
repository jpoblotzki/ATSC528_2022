# %% [markdown]
# # **Assignment: 04- Chaos**
# #### **Author: Julia Poblotzki**
# #### **Due: December 9, 2022 @ 11:59pm**
# ###### _______________________________________________________________________________
# ##### *Created By    : Jared W. Marquis*
# ##### *Creation Date : 01 August 2022*
# ##### *Course        : ATSC 528 - Atmospheric Data Analysis*
# ##### *Assignment    : 04 - Chaos*
# ###### _______________________________________________________________________________
# ### **Purpose:** *Script to examine how chaos manifests in a simple model.*
#
# We are taking three equations that simulate a large-scale atmospheric wave and varying the initial conditions slightly to analyze how the end results differ. This is supposed to represent, or show, how our atmosphere (and in turn, weather), are chaotic dynamic systems, where slight changes in initial conditions can lead to drastic changes in end results, a.k.a. Chaos Theory.
#
# The wave is represented by the following equations *(Lorenz, 1984; 1990; 2006)*:
# * the strength of a circumpolar westerly current: $ dx/dt = -y² - z² -ax +aF $
# * cosine phase of a superimposed chain of large-scale waves: $ dy/dt = xy - bxz - y + G $
# * sine phase of a superimposed chain of large-scale waves: $ dz/dt = bxy + xz -z $
#
# --> $ t $ is a normalized time such that 1 normalized time unit equals 5 days and $ a $, $ b $, $ F $, and $ G $ are constants
#
# ## __incipiam~__

# %%
### Import Required Modules ###
import numpy as np                 #numpy for math
import matplotlib.pyplot as plt    #matplotlib for plotting
import cartopy.crs as ccrs         #cartopy for plotting on map
import cartopy.feature as cfeature #cartopy basic shapefiles
from mpl_toolkits import mplot3d   #for 3D plotting

# %% [markdown]
# ## **Defining Variables**

# %%
#Lorenz(1984,1990,2006) dif. eq. constants
a = 0.25
b = 4.0
F = 8.0
G = 1.0


#initial conditions for the two simulations
xo = np.array([2.5, 2.49])
yo = np.array([1.0, 1.0])
zo = np.array([0.0, 0.0])


# Timestep
t = 4 / (24*5) #normalized time step since equations are normalized to 5 days

#time array
end_time = 120/5 #normalized to 5 days, so need to adjust end time as such
time = np.arange(0,end_time,t)

# %% [markdown]
# ## **Perform the 2 Simulations**
# ##### Use 2 different initial conditions & solve the system of equations using forward time differencing:
# * $ x(t+dt) = x(t) + dt[-y(t)² - z(t)² - [a*x(t)] + [a*F]] $
#
# * $ y(t+dt) = y(t) + dt[ [x(t)*y(t)] - [b * x(t) * z(t)] - y(t) + G] $
#
# * $ z(t+dt) = z(t) + dt[[b*x(t)*y(t)] + [x(t)*z(t)] - z(t)] $

# %%
#define empty arrays to be filled later
x = np.zeros((len(time), len(xo)))
y = np.zeros((len(time), len(yo)))
z = np.zeros((len(time), len(zo)))


#fill in the first timestep with the initial conditions
x[0,0] = xo[0]
x[0,1] = xo[1]

y[0,0] = yo[0]
y[0,1] = yo[1]

z[0,0] = zo[0]
z[0,1] = zo[1]


#run the simulations out to 120 days (real time)
#use the 'previous values' [i] to calculate the 'current values' [i+1]
for m in range(len(xo)):
    for i in range(len(time)-1):
        x[(i+1),m] = x[i,m] + (t * (-((y[i,m])**2) - ((z[i,m])**2) - (a * x[i,m]) + (a*F)))
        y[(i+1),m] = y[i,m] + (t * ((x[i,m]*y[i,m]) - (b*x[i,m]*z[i,m]) - y[i,m] + G))
        z[(i+1),m] = z[i,m] + (t * ((b*x[i,m]*y[i,m]) + (x[i,m]*z[i,m]) - z[i,m]))

# %% [markdown]
# ### **Calculate the Differences Between the Simulations**

# %%
diff_x = x[:,1] - x[:,0]
diff_y = y[:,1] - y[:,0]
diff_z = z[:,1] - z[:,0]

# %% [markdown]
# ## **Plotting Time**
# - Simulation 1
# - Simulation 2
# - Simulations 1 & 2
# - Differences Between the 2
# - 3D plots because they looked cool

# %%
## Simulation 1


fig = plt.figure(figsize=(15,5),dpi=200)
ax1 = fig.add_subplot(131)
ax1.plot(time*5, x[:,0], c='steelblue')
plt.ylabel('strength of a circumpolar westerly current')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(132)
ax1.plot(time*5, y[:,0], c='steelblue')
plt.ylabel('cosine phases')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(133)
ax1.plot(time*5, z[:,0], c='steelblue')
plt.ylabel('sine phases')
plt.xlabel('Time (days)')
plt.grid()

plt.suptitle('Simulation 1')
plt.tight_layout()

#plt.savefig("C:\\Users\\julia\\Documents\\GitHub\\ATSC528_2022\\04-Chaos\\Sim_1.png")
plt.show()

# %%
## Simulation 2


fig = plt.figure(figsize=(15,5),dpi=200)
ax1 = fig.add_subplot(131)
ax1.plot(time*5, x[:,1], c='olivedrab')
plt.ylabel('strength of a circumpolar westerly current')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(132)
ax1.plot(time*5, y[:,1], c='olivedrab')
plt.ylabel('cosine phases')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(133)
ax1.plot(time*5, z[:,1], c='olivedrab')
plt.ylabel('sine phases')
plt.xlabel('Time (days)')
plt.grid()

plt.suptitle('Simulation 2')
plt.tight_layout()

#plt.savefig("C:\\Users\\julia\\Documents\\GitHub\\ATSC528_2022\\04-Chaos\\Sim_2.png")
plt.show()

# %%
## Simulations 1 & 2


fig = plt.figure(figsize=(15,5),dpi=200)
ax1 = fig.add_subplot(131)
ax1.plot(time*5, x[:,0], c='steelblue')
ax1.plot(time*5, x[:,1], c='olivedrab')
ax1.legend(['Simulation 1', 'Simulation 2'])
plt.ylabel('strength of a circumpolar westerly current')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(132)
ax1.plot(time*5, y[:,0], c='steelblue')
ax1.plot(time*5, y[:,1], c='olivedrab')
ax1.legend(['Simulation 1', 'Simulation 2'])
plt.ylabel('cosine phases')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(133)
ax1.plot(time*5, z[:,0], c='steelblue')
ax1.plot(time*5, z[:,1], c='olivedrab')
ax1.legend(['Simulation 1', 'Simulation 2'])
plt.ylabel('sine phases')
plt.xlabel('Time (days)')
plt.grid()

plt.suptitle('Both Simulations')
plt.tight_layout()

#plt.savefig("C:\\Users\\julia\\Documents\\GitHub\\ATSC528_2022\\04-Chaos\\Sim_1_and_Sim_2.png")
plt.show()

# %%
## Differences


fig = plt.figure(figsize=(15,5),dpi=200)
ax1 = fig.add_subplot(131)
ax1.plot(time*5, diff_x, c='Teal')
plt.ylabel('strength of a circumpolar westerly current')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(132)
ax1.plot(time*5, diff_y, c='Teal')
plt.ylabel('cosine phases')
plt.xlabel('Time (days)')
plt.grid()

ax1 = fig.add_subplot(133)
ax1.plot(time*5, diff_z, c='Teal')
plt.ylabel('sine phases')
plt.xlabel('Time (days)')
plt.grid()

plt.suptitle('Simulation Differences')
plt.tight_layout()

#plt.savefig("C:\\Users\\julia\\Documents\\GitHub\\ATSC528_2022\\04-Chaos\\Sim_2-Sim_1.png")
plt.show()

# %%
## 3D Plots

fig = plt.figure(figsize=(10,4.5),dpi=200)
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter3D(x[:,0],y[:,0],z[:,0], c=z[:,0], cmap = 'Blues')
plt.title('Simulation 1')
ax.set_xlabel('strength of a circumpolar westerly current')
ax.set_ylabel('cosine phases')
ax.set_zlabel('sine phases')

ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.scatter3D(x[:,1],y[:,1],z[:,1], c=z[:,1], cmap = 'Greens')
plt.title('Simulation 2')
ax.set_xlabel('strength of a circumpolar westerly current')
ax.set_ylabel('cosine phases')
ax.set_zlabel('sine phases')

plt.tight_layout()

#plt.savefig("C:\\Users\\julia\\Documents\\GitHub\\ATSC528_2022\\04-Chaos\\3D_Sim_Plots.png")
plt.show()

# %%
'''
### Store the analyses in text files ###
with open('strength_of_a_circumpolar_westerly_current.txt', 'wb') as f:
    for line in x:
        np.savetxt(f, line)
        
with open('cosine_phases.txt', 'wb') as f:
    for line in y:
        np.savetxt(f, line)

with open('sine_phases.txt', 'wb') as f:
    for line in z:
        np.savetxt(f, line)
'''
# Out:
# "\n### Store the analyses in text files ###\nwith open('strength_of_a_circumpolar_westerly_current.txt', 'wb') as f:\n    for line in x:\n        np.savetxt(f, line)\n        \nwith open('cosine_phases.txt', 'wb') as f:\n    for line in y:\n        np.savetxt(f, line)\n\nwith open('sine_phases.txt', 'wb') as f:\n    for line in z:\n        np.savetxt(f, line)\n"

# %% [markdown]
# ## __~finis code__

# %% [markdown]
# ### In a separate text file, provide a discussion of your results. Make sure to answer the following questions in your discussion:
#
# 1 - Are the two simulations the same throughout the entire period? If not, when do they diverge?
#
#     The two simulations are not the same throughout the entire period. At the beginning they are quite similar, but then they diverge and end at quite different values. Both the wave amplitudes and timing of the waves are different.
#
#     Looking at the plot that has both simulation plotted, major differences in the two simulations occurs visually at about 55 days for the x-values; minorly at 38, but majorly starting at about 60 days for y-values; and at about 65 days for z-values. Thus, for x, y, and z the divergence all starts to occur majorly at around the same time.
#
#     Looking at the differences plot, the first 20 days look okay, as in around 0. The x-values start to differ greatly at about 70 days before the differences sky rocket. The two simulations seem to have their cosine phases out of phase at about the 50 day mark and then are just terribly off after 70 days. The sine phases go out of phase at about 50 days and then sky rocket after 70.
#
#     Overall, the simulations start out about the same but the differences become larger as time goes on. It's a classic snowball effect that demonstrates how Chaos Theory evolves.
#
# 2 - If the ending points are different, what does this say regarding the importance of providing NWP models, assuming this serves as a proxy for one, with accurate and balanced initial conditions?
#
#     The ending points are similar for z, but not the same, wheras they are very off for x & y. Looking at the differences plot, none of x, y, or z end at a difference of 0. Also, seeing as how the difference plot had greater amplitudes as time increased, it shows how 'errors' or small differences can multiply and become greater. This emphasizes the need for accurate initial conditions since small differences can have drastic endings. For example, varying your initial conditions 1°C could lead to a calm day vs a tornado (two very different scenarios).
#
#     Additionally, since our analyses are often using our previous' analysis values (see: Data Assimilation Cycle), even though the first 'run' was only off by 0.01, the following runs would differ in starting conditions by a lot more (maximum difference for each plot (absolute value): x=1.8, y=2.5, and z=2.4) which would lead to even more extreme differences as time goes on. If there's an error in your initial conditions, weather will call you out and make those differences even more noticable. Our initial conditions were the same for y & z, but off by 0.01 for x. At some point the plots were off by 250 times that (yikes).
#
#     If we assume Simualtion 1 to be our truth (aka sooth), but our observations supplied us with Simuation 2's initial conditions, our model would have a large error and thus our weather forecasts would be off (and everyone would hate us). Thus, it is important to be as close to truth as possible, so that we have as little error as possible.
